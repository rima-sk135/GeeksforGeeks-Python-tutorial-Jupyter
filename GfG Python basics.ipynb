# %%
print("Hello World, this is Python basics.")
# Out:
# Hello World, this is Python basics.

# %%
#this is a single line comment

# %%
""" this is a
multiple line
comment"""
# Out:
# ' this is a\nmultiple line\ncomment'

# %% [markdown]
# **Rules for naming Variables**
# 1. must start with a letter or an underscore
# 2. cannot start with a number
# 3. can only contain alphanumeric characters and underscore
# 4. case sensitive (name, Name, NAME are different variables)
# 5. some reserved words cannot be used as a variable name

# %% [markdown]
# Finding the type of a variable

# %%
#to find the type of a variable we use the command **print(type(variable))

# %% [markdown]
# **String Assignment**

# %%
name = "Geek for Geeks"

# %%
print(name, (type(name)))
# Out:
# Geek for Geeks <class 'str'>

# %% [markdown]
# **Integer Assignment**

# %%
age = 21

# %%
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# **Floating-Point assignment**

# %%
salary = 28.6

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
x = "Hello World" #string

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = 21 #integer

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 23.7 #float

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
x =3j #complex

# %%
print (x, type (x))
# Out:
# 3j <class 'complex'>

# %%
x = ["geeks", "for", "geeks"] #list

# %%
print (x, type(x))
# Out:
# ['geeks', 'for', 'geeks'] <class 'list'>

# %%
x = ("geeks", "for", "geeks") #tuple

# %%
print (x, type(x))
# Out:
# ('geeks', 'for', 'geeks') <class 'tuple'>

# %%
x = {"name": "Suraj", "age": 24} #dictionary

# %%
print (x, type(x))
# Out:
# {'name': 'Suraj', 'age': 24} <class 'dict'>

# %%
x = {"geeks", "for", "geeks"} #set

# %%
print(x, type(x))
# Out:
# {'geeks', 'for'} <class 'set'>

# %%
x = True #boolean

# %%
print(x)
# Out:
# True

# %%
x = b"Geeks" #binary 'bytes'

# %%
print(x)
# Out:
# b'Geeks'

# %% [markdown]
# **Input/Output**

# %%
val = input("Enter your value: ")
# Out:
# Enter your value:  21

# %%
print("You entered: ", val)
# Out:
# You entered:  21

# %% [markdown]
# **The input() function** in Python always returns data as a string, regardless of what the user enters. If we want to store the input as another data type (like int, float, etc.), we need to explicitly convert (typecast) it.

# %%
name = input("Enter your name: ")
# Out:
# Enter your name:  RIMA

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
age = input("Enter your age: ")
# Out:
# Enter your age:  22

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age = int(input("Enter your age: ")) #we are typecasting age as a integer
# Out:
# Enter your age:  22

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(age)
# Out:
# 22

# %% [markdown]
# **Arithmatic Operators** -- +, -,*, /, //, %, **

# %%
a = 9

# %%
b = 4

# %%
add = a + b

# %%
sub = a - b

# %%
mul = a * b

# %%
div = a/b

# %%
mod = a%b

# %%
exponent = a**b

# %%
print(add, sub, mul, div, mod, exponent)
# Out:
# 13 5 36 2.25 1 6561

# %%
print(a//b)
# Out:
# 2

# %% [markdown]
# **Comparison Operators**

# %%
a = 10

# %%
b = 20

# %%
print(a==b) #is equal to?
# Out:
# False

# %%
print(a!=b) #is not equal to?
# Out:
# True

# %%
print(a>b)
# Out:
# False

# %%
print(a<b)
# Out:
# True

# %%
print(a>=b)
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %% [markdown]
# **Logical Operator**

# %%
a = True

# %%
b = False

# %%
print(a and b)
# Out:
# False

# %%
print(a or b)
# Out:
# True

# %%
print(not b)
# Out:
# True

# %% [markdown]
# **Bitwise Operators**
#
# Python Bitwise operators act on bits and perform bit-by-bit operations. These are used to operate on binary numbers. Types of bitwise operators: &, |, ^, ~, <<, >>

# %%
a = 10

# %%
b = 4

# %%
print(a & b)
# Out:
# 0

# %%
print(a|b)
# Out:
# 14

# %%
print(~a)
# Out:
# -11

# %%
print(a^b)
# Out:
# 14

# %%
print(a>>2)
# Out:
# 2

# %%
print(a<<2)
# Out:
# 40

# %% [markdown]
# **Assignment Operators**
#
# Python Assignment operators are used to assign values to the variables. Types of assignment operators: =, +=, -=, *=, /=, %=, **=, //=, &=, |=, ^=, >>=, <<=​.

# %%
a=10

# %%
b=a

# %%
print(b)
# Out:
# 10

# %%
b+=a #b=b+a

# %%
print(b)
# Out:
# 20

# %%
b-=a

# %%
print(b)
# Out:
# 10

# %%
b*=a

# %%
print(b)
# Out:
# 100

# %%
b<<=a

# %%
print(b)
# Out:
# 102400

# %% [markdown]
# **Python If Else**
#
# In Python, the if statement is used to run a block of code only when a specific condition is true. If the condition is false and you want to run a different block of code, you can use the else statement. This allows your program to make decisions and respond differently based on conditions.

# %%
i=10
if (i<15):
    print("i is smaller than 15")
    print("I'm in the if block")
else:
    print("i is greater than 15")
    print("I'm in else block")
print("I'm not in if block and not in else block")
# Out:
# i is smaller than 15
# I'm in the if block
# I'm not in if block and not in else block

# %% [markdown]
# **Python if-elif-else ladder**
#
# Sometimes, we need to check multiple conditions. In such cases, Python provides the if-elif-else structure.

# %%
i = 15
if i == 10:
    print("i is 10")
elif i == 15:
    print("i is 15")
elif i == 20:
    print("i is 20")
else:
    print("i is not present")
# Out:
# i is 15

# %% [markdown]
# **Python Loops**

# %% [markdown]
# **For Loop**
#
# Python For loop is used for sequential traversal i.e. it is used for iterating over an iterable like String, Tuple, List, Set, or Dictionary. Here, we will see a "for" loop in conjunction with the range() function to generate a sequence of numbers starting from 0, up to (but not including) 10, and with a step size of 2. For each number in the sequence, the loop prints its value using the print() function.

# %%
for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
"""#Explanation:
range(0, 10, 2) generates numbers: 0, 2, 4, 6, 8.
The loop prints each number on a new line."""
# Out:
# '#Explanation:\nrange(0, 10, 2) generates numbers: 0, 2, 4, 6, 8.\nThe loop prints each number on a new line.'

# %% [markdown]
# **While Loop**
#
# A while loop continues to execute as long as a condition is True. In this example, the condition for while will be True as long as the counter variable (count) is less than 3.

# %%
count = 0
while(count<3):
    count = count+1
    print("Hello Geeks")
# Out:
# Hello Geeks
# Hello Geeks
# Hello Geeks

# %%
'''Explanation:
The loop runs 3 times because count goes from 0 - 1 - 2.
Once count becomes 3, the condition count < 3 becomes False and the loop stops.'''
# Out:
# 'Explanation:\nThe loop runs 3 times because count goes from 0 - 1 - 2.\nOnce count becomes 3, the condition count < 3 becomes False and the loop stops.'

# %% [markdown]
# **Python Functions:**
# Python Function is a block of reusable code that performs a specific task. Functions help make your code modular, readable, and easier to debug.
#
# There are two main types of functions in Python:
#
# 1. Built-in functions like print(), len(), type()
# 2. User-defined functions created using the def keyword

# %% [markdown]
# **Example:** User-Defined Function to Check Even/Odd

# %%
def evenOdd(x):
    if x%2 == 0:
        print("the value is even")
    else:
        print("the value is odd")

# %%
evenOdd(5)
# Out:
# the value is odd

# %% [markdown]
# **Explanation:**
#
# The function evenOdd(x) checks if x is divisible by 2.
# If it is, it prints "even"; otherwise, "odd".

# %% [markdown]
# **Input/Output in detail**

# %%
name = input("Enter your name: ")
# Out:
# Enter your name:  Rima

# %%
print("Hello, ", name, "! Welcome!")
# Out:
# Hello,  Rima ! Welcome!

# %%
#taking multiple(2) inputs at a time

# %%
x, y = input("Enter two values: ").split()
# Out:
# Enter two values:  21, 22

# %%
print("Number of boys: ", x)
# Out:
# Number of boys:  21,

# %%
print("Number of girls: ", y)
# Out:
# Number of girls:  22

# %%
#taking three inputs at a time

# %%
x, y, z = input("Enter three values: ").split()
# Out:
# Enter three values:  22, 22, 24

# %%
print("Total number of students: ", x)
# Out:
# Total number of students:  22,

# %%
print("Total number of boys: ", y)
# Out:
# Total number of boys:  22,

# %%
print("Total number of girls: ", z)
# Out:
# Total number of girls:  24

# %% [markdown]
# **Take Conditional Input from user in Python**
#
# In this example, the program prompts the user to enter their age. The input is converted to an integer using the int() function. Then, the program uses conditional statements to check the age range and prints a message based on whether the user is a minor, an adult, or a senior citizen.

# %%
age_input = input("Enter your age: ") #Prompting the user for input
# Out:
# Enter your age:  22

# %%
age = int(age_input) #converting the age input into an integer

# %%
#Checking conditions based on user input

# %%
if age < 0:
    print("Please enter valid age!")
elif age < 18:
    print("You are a minor.")
elif age >= 18 and age <= 60:
    print("You are an adult.")
else:
    print("You are a senior citizen.")
# Out:
# You are an adult.

# %% [markdown]
# **Print Float/Decimal Number in Python**
#
# The code prompts the user to input the price of each rose as a floating-point number, converts the input to a float using typecasting and then prints the price.

# %%
#taking input as float

# %%
#typecasting as float

# %%
weight = float(input("How much do you weigh? "))
# Out:
# How much do you weigh?  56

# %% [markdown]
# **Output Formatting**
#
# Output formatting in Python with various techniques including the format() method, manipulation of the sep and end parameters, f-strings and the versatile % operator. These methods enable precise control over how data is displayed, enhancing the readability and effectiveness of your Python programs.

# %%
amount = 150.50

# %%
print("Amount:${:.2f}".format(amount))
# Out:
# Amount:$150.50

# %%
print(type(amount))
# Out:
# <class 'float'>

# %% [markdown]
# The term 'loc' in Python usually refers to a label-based data selection method used with pandas, a popular library for data manipulation and analysis. What 'loc' Means in Pandas
#
# 'loc' accesses rows and columns in a DataFrame by their labels (not positions).
#
# It’s commonly used when your DataFrame has meaningful index labels or column names.
